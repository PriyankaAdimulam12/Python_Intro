# %% [markdown]
# <a href="https://colab.research.google.com/github/PriyankaAdimulam12/Python_Intro/blob/main/Pandas_introduction_updated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd

# %%
df=pd.read_csv('Salaries.csv')

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.tail(10)
# Out:
#          rank discipline  phd  service     sex  salary
# 68   AsstProf          A    4        2  Female   77500
# 69       Prof          A   28        7  Female  116450
# 70   AsstProf          A    8        3  Female   78500
# 71  AssocProf          B   12        9  Female   71065
# 72       Prof          B   24       15  Female  161101
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.shape
# Out:
# (78, 6)

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
df.isnull()
# Out:
#      rank  discipline    phd  service    sex  salary
# 0   False       False  False    False  False   False
# 1   False       False  False    False  False   False
# 2   False       False  False    False  False   False
# 3   False       False  False    False  False   False
# 4   False       False  False    False  False   False
# ..    ...         ...    ...      ...    ...     ...
# 73  False       False  False    False  False   False
# 74  False       False  False    False  False   False
# 75  False       False  False    False  False   False
# 76  False       False  False    False  False   False
# 77  False       False  False    False  False   False
#
# [78 rows x 6 columns]

# %%
pd.set_option('display.max_rows',None)
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.isnull()
# Out:
#      rank  discipline    phd  service    sex  salary
# 0   False       False  False    False  False   False
# 1   False       False  False    False  False   False
# 2   False       False  False    False  False   False
# 3   False       False  False    False  False   False
# 4   False       False  False    False  False   False
# 5   False       False  False    False  False   False
# 6   False       False  False    False  False   False
# 7   False       False  False    False  False   False
# 8   False       False  False    False  False   False
# 9   False       False  False    False  False   False
# 10  False       False  False    False  False   False
# 11  False       False  False    False  False   False
# 12  False       False  False    False  False   False
# 13  False       False  False    False  False   False
# 14  False       False  False    False  False   False
# 15  False       False  False    False  False   False
# 16  False       False  False    False  False   False
# ...

# %%
df.isnull().sum()
# Out:
# rank          0
# discipline    0
# phd           0
# service       0
# sex           0
# salary        0
# dtype: int64

# %%
df['salary']
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
# 5     122400
# 6      81285
# 7     126300
# 8      94350
# 9      57800
# 10    128250
# 11    134778
# 12     88000
# 13    162200
# 14    153750
# 15    150480
# 16     75044
# 17     92000
# 18    107300
# 19    150500
# 20     92000
# 21    103106
# 22     73000
# 23     85000
# 24     91100
# 25     99418
# 26    148750
# 27    155865
# 28     91300
# 29    123683
# 30    107008
# 31    155750
# 32    103275
# 33    120000
# 34    119800
# 35    126933
# 36    146856
# 37    102000
# 38     91000
# 39    129000
# 40    137000
# 41     74830
# 42     80225
# 43     77000
# 44    151768
# 45    140096
# 46     74692
# 47    103613
# 48    111512
# 49    122960
# 50     97032
# 51    127512
# 52    105000
# 53     73500
# 54     62884
# 55     72500
# 56     77500
# 57     72500
# 58    144651
# 59    103994
# 60     92000
# 61    103750
# 62    109650
# 63     91000
# 64     73300
# 65    117555
# ...

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df['salary'].mean()
# Out:
# np.float64(108023.78205128205)

# %%
df['salary'][1]
# Out:
# np.int64(93000)

# %%
df['salary'].median()
# Out:
# 104671.0

# %%
df['salary'].mode()
# Out:
# 0    92000
# Name: salary, dtype: int64

# %%
df['salary'].var()
# Out:
# 800531254.0427904

# %%
df['salary'].std()
# Out:
# 28293.661022264165

# %%
df['salary'].skew()
# Out:
# np.float64(0.45210256755588096)

# %%
df['salary'].kurt()
# Out:
# np.float64(-0.4017126758820546)

# %%
df['salary'].max()
# Out:
# 186960

# %%
df['salary'].min()
# Out:
# 57800

# %%
df[['salary','service']].mean()
# Out:
# salary     108023.782051
# service        15.051282
# dtype: float64

# %%
import warnings
warnings.filterwarnings('ignore')
# Select only numeric columns before calculating the mean
numeric_df = df.select_dtypes(include=['number'])
display(numeric_df.mean())
# Out:
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df[df['salary']>120000]
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 3   Prof          A   40       31    Male  131205
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 26  Prof          A   38       19    Male  148750
# 27  Prof          A   45       43    Male  155865
# 29  Prof          B   21       20    Male  123683
# 31  Prof          B   22       21    Male  155750
# 35  Prof          B   28       23    Male  126933
# 36  Prof          B   45       45    Male  146856
# 39  Prof          B   18       18  Female  129000
# 40  Prof          A   39       36  Female  137000
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.max()
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
df['rank'].value_counts()
##this way we can find out how many catagory in the observation
# Out:
# rank
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: count, dtype: int64

# %%
df.iloc[:,:]  #anything before comma is rows and after comma is columns
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.iloc[0:50,:]  #iloc-index location
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.iloc[0:50,[1,3,5]]  # 50 rows and column 1,3 and 5
# Out:
#    discipline  service  salary
# 0           B       49  186960
# 1           A        6   93000
# 2           A       20  110515
# 3           A       31  131205
# 4           B       18  104800
# 5           A       20  122400
# 6           A       17   81285
# 7           A       18  126300
# 8           A       19   94350
# 9           A       51   57800
# 10          B       33  128250
# 11          B       23  134778
# 12          B        0   88000
# 13          B       33  162200
# 14          B       19  153750
# 15          B        3  150480
# 16          B        3   75044
# 17          B        0   92000
# 18          A        7  107300
# 19          A       27  150500
# 20          B        4   92000
# 21          A       30  103106
# 22          A        2   73000
# 23          A        0   85000
# 24          A       23   91100
# 25          B       31   99418
# 26          A       19  148750
# 27          A       43  155865
# 28          B        2   91300
# ...

# %%
df['rank'].max()
# Out:
# 'Prof'

# %%
df.groupby(['rank']).mean(numeric_only=True)
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
 df['phd'].count()
# Out:
# np.int64(78)

# %%
df.groupby('rank')[['salary','phd']].mean(numeric_only=True)
# Out:
#                   salary        phd
# rank
# AssocProf   91786.230769  15.076923
# AsstProf    81362.789474   5.052632
# Prof       123624.804348  27.065217

# %%
df.iloc[1:4,0:3]
# Out:
#    rank discipline  phd
# 1  Prof          A   12
# 2  Prof          A   23
# 3  Prof          A   40

# %%
df.iloc[0:2,]
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000

# %%
df.iloc[:,4]
# Out:
# 0       Male
# 1       Male
# 2       Male
# 3       Male
# 4       Male
# 5       Male
# 6       Male
# 7       Male
# 8       Male
# 9       Male
# 10      Male
# 11      Male
# 12      Male
# 13      Male
# 14      Male
# 15      Male
# 16      Male
# 17      Male
# 18      Male
# 19      Male
# 20      Male
# 21      Male
# 22      Male
# 23      Male
# 24      Male
# 25      Male
# 26      Male
# 27      Male
# 28      Male
# 29      Male
# 30      Male
# 31      Male
# 32      Male
# 33      Male
# 34      Male
# 35      Male
# 36      Male
# 37      Male
# 38      Male
# 39    Female
# 40    Female
# 41    Female
# 42    Female
# 43    Female
# 44    Female
# 45    Female
# 46    Female
# 47    Female
# 48    Female
# 49    Female
# 50    Female
# 51    Female
# 52    Female
# 53    Female
# 54    Female
# 55    Female
# 56    Female
# 57    Female
# 58    Female
# 59    Female
# 60    Female
# 61    Female
# 62    Female
# 63    Female
# 64    Female
# 65    Female
# ...

# %% [markdown]
# # Visualizations using Matplotlib & Seaborn library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv('Universities.csv')

# %%
df1
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
plt.figure(figsize=(4,4)) #you can adjust the figure size..
plt.hist(df1['Accept']) #here accept is column..df1 is the dataframe u stored in..
plt.xlabel('Accept')
plt.ylabel('count')
plt.title('histogram of accept')
plt.show() # used to remove the values, when you run only 2nd line..

# %%
plt.figure(figsize=(4,4))
plt.hist(df1['SAT'])
plt.xlabel('SAT') #now we did hist for another column..
plt.ylabel('count')
plt.title('histogram of SAT')
plt.show()

# %%
sns.histplot(df1['Accept']) #you can also create histogram using the SEABORN library as well
# you get more cleaner visualization using seaborn & more options as well..
# Out:
# <Axes: xlabel='Accept', ylabel='Count'>

# %%
sns.histplot(df1['SAT'])
# Out:
# <Axes: xlabel='SAT', ylabel='Count'>

# %%
sns.distplot(df1['Accept']) #its like a histogram,but you can also see your frequency distribution(curve) as well.. I
# USE THESE IF YOU SEE ANY WARNINGSS, import warnings
#warnings.filterwarnings('ignore')
# Out:
# <Axes: xlabel='Accept', ylabel='Density'>

# %% [markdown]
# Scatter Plots..

# %%
plt.plot(df1['Accept'],df1['Expenses'],'r+') #here x axis is Accept & y axis is Expenses.'bo' gives bluecircles in scatter plot.likewise u can try 'rs' means red square.
plt.xlabel('Accept')
plt.ylabel('Expenses')
plt.title('Scatterplot Accept vs Expenses')
# Out:
# Text(0.5, 1.0, 'Scatterplot Accept vs Expenses')

# %%
#so if u want to know about any function,like plot etc
help(plt.plot)
help(plt.hist)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args: 'float | ArrayLike | str', scalex: 'bool' = True, scaley: 'bool' = True, data=None, **kwargs) -> 'list[Line2D]'
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
#it creates all possible ways of creating histogram & scatter plot with all numerical columns
sns.pairplot(df1)

# %%
df1.iloc[:,:]
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
df1.iloc[0:10,:]
# Out:
#            Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0         Brown  1310     89      22       13     22704        94
# 1       CalTech  1415    100      25        6     63575        81
# 2           CMU  1260     62      59        9     25026        72
# 3      Columbia  1310     76      24       12     31510        88
# 4       Cornell  1280     83      33       13     21864        90
# 5     Dartmouth  1340     89      23       10     32162        95
# 6          Duke  1315     90      30       12     31585        95
# 7    Georgetown  1255     74      24       12     20126        92
# 8       Harvard  1400     91      14       11     39525        97
# 9  JohnsHopkins  1305     75      44        7     58691        87

# %%
df1.iloc[0:10,0:3]
# Out:
#            Univ   SAT  Top10
# 0         Brown  1310     89
# 1       CalTech  1415    100
# 2           CMU  1260     62
# 3      Columbia  1310     76
# 4       Cornell  1280     83
# 5     Dartmouth  1340     89
# 6          Duke  1315     90
# 7    Georgetown  1255     74
# 8       Harvard  1400     91
# 9  JohnsHopkins  1305     75

# %%
df1.iloc[0:10,[0,2,5]]
# Out:
#            Univ  Top10  Expenses
# 0         Brown     89     22704
# 1       CalTech    100     63575
# 2           CMU     62     25026
# 3      Columbia     76     31510
# 4       Cornell     83     21864
# 5     Dartmouth     89     32162
# 6          Duke     90     31585
# 7    Georgetown     74     20126
# 8       Harvard     91     39525
# 9  JohnsHopkins     75     58691

# %%
#this creates pairplot with all rows & from 1,2,3 columns, as 0 column is names of univeristy we cant consider it..we take onlyt numerical columns
sns.pairplot(df1.iloc[:,1:4])

# %%
sns.pairplot(df1.iloc[:,1:3])

# %%
# we can create boxplot
plt.boxplot(df1['Accept'])
plt.show()

# %%
df1.describe()  #you can also get statistical measures for all numerical columns
# Out:
#                SAT       Top10     Accept   SFRatio      Expenses   GradRate
# count    25.000000   25.000000  25.000000  25.00000     25.000000  25.000000
# mean   1266.440000   76.480000  39.200000  12.72000  27388.000000  86.720000
# std     108.359771   19.433905  19.727308   4.06735  14424.883165   9.057778
# min    1005.000000   28.000000  14.000000   6.00000   8704.000000  67.000000
# 25%    1240.000000   74.000000  24.000000  11.00000  15140.000000  81.000000
# 50%    1285.000000   81.000000  36.000000  12.00000  27553.000000  90.000000
# 75%    1340.000000   90.000000  50.000000  14.00000  34870.000000  94.000000
# max    1415.000000  100.000000  90.000000  25.00000  63575.000000  97.000000

# %%
df1['Accept'].describe() #you can also get statistical measures for particular column as well
# Out:
# count    25.000000
# mean     39.200000
# std      19.727308
# min      14.000000
# 25%      24.000000
# 50%      36.000000
# 75%      50.000000
# max      90.000000
# Name: Accept, dtype: float64

# %% [markdown]
# Note:So these visualizations are created when we are solving our datascience &machine learning problems

# %%
plt.boxplot(df1['Accept'],vert = False) #this gives us horizontal boxplot
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x785afbd59550>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x785afbd5a950>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x785afbd588d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x785afbd5bd50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x785afbd64850>],
#  'means': []}

# %%
plt.boxplot(df1['Accept'],vert = True)  #this gives us vertical boxplot
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x785afbbbda90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x785afbbbf290>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x785afbbbd190>],
#  'medians': [<matplotlib.lines.Line2D at 0x785afbbc0b50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x785afbbc1510>],
#  'means': []}

# %% [markdown]
# # Numpy

# %%
import numpy as np

# %%
a=np.array([1,2,3,4]) # this is one dimensional array
print(a)
# Out:
# [1 2 3 4]

# %%
type(a) #this tells us this is numpy array
# Out:
# numpy.ndarray

# %%
a.size #this will tell us how many elements are there in our array
# Out:
# 4

# %%
a.shape #this means that (rows,columns) & here as it is 1-dimensional array, it has 4 rows and no columns
# Out:
# (4,)

# %%
#All the dataset we have worked so far has 2-dimensional array..lets see the below..

# %%
df1.shape #so this dataset(university) has 25 rows and 7 columns
# Out:
# (25, 7)

# %%
#so we can do the following oprations with our array..

# %%
a.min()
# Out:
# np.int64(1)

# %%
a.max()
# Out:
# np.int64(4)

# %%
a.sum()
# Out:
# np.int64(10)

# %%
a.prod()
# Out:
# np.int64(24)

# %%
b=np.array([(1,2,3,4),(4,5,6,7)]) #we created 2 dimensional array

# %%
print(b)
# Out:
# [[1 2 3 4]
#  [4 5 6 7]]

# %%
b.shape #this meansit has 2 rows and 4 columns..
# Out:
# (2, 4)

# %%
b.size #this means it has 8 elements..
# Out:
# 8

# %%
c=b.reshape(4,2) #this reshapes our array,
#previously we had 2 rows & 4 columns
#Now we Reshape to 4 rows and 2 columns

# %%
c
# Out:
# array([[1, 2],
#        [3, 4],
#        [4, 5],
#        [6, 7]])

# %%
c.shape
# Out:
# (4, 2)

# %%
c[0][0]
#this shows the VALUE present in 0th Row & 0th Column
# Out:
# np.int64(1)

# %%
c[1].min() #this shows the min value in 1st row
# Out:
# np.int64(3)

# %%
c.sum(axis=0) #axis=0 is row wise calculation..
#1+3+4+6,2+4+5+7
# Out:
# array([14, 18])

# %%
c.sum(axis=1) #1+2,3+4,4+5,6+7
# Out:
# array([ 3,  7,  9, 13])

# %% [markdown]
# # Duplicates

# %% [markdown]
# So fare we have seen datsets like salaries, universities..
# You can also create datset, so u can create using using ur "pandas library" with Dataframe..

# %%
df2=pd.DataFrame({'col1':['A','A','B','B','B'],'col2':[2,2,2,3,3]})
#we created a dataframe,now we will see what is the purpose..
df2
# Out:
#   col1  col2
# 0    A     2
# 1    A     2
# 2    B     2
# 3    B     3
# 4    B     3

# %%
df2.duplicated() #this tells us the duplicated values,i.e the repeated values in or dataframe..
#false means its not duplicated,  true means which is duplicated,i.e the repeated ones
#we can say that our data has repeting values
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
df2[df2.duplicated()] # this shows us the duplicated records
# Out:
#   col1  col2
# 1    A     2
# 4    B     3

# %%
#we can drop the duplicated records..
df3=df2.drop_duplicates()
df3
#output shows the record without the duplicated values
# Out:
#   col1  col2
# 0    A     2
# 2    B     2
# 3    B     3

# %%
 df3
 #this is our output right,but here the index are not in a order 0,2,3..
 #so we need to rearrange the index in a order..
# Out:
#   col1  col2
# 0    A     2
# 2    B     2
# 3    B     3

# %%
df4=df3.reset_index()
#so here we have reset the index,now you need to drop the previous index column..

# %%
df4
# Out:
#    index col1  col2
# 0      0    A     2
# 1      2    B     2
# 2      3    B     3

# %%
df5=df4.drop('index',axis=1)
df5
# Out:
#   col1  col2
# 0    A     2
# 1    B     2
# 2    B     3

# %% [markdown]
# # Data structures

# %%
#List
#it is a structure of data for storing information,whether its numerical or non numerical..
#everthing should be enclosed in []

# %%
d=[1,2,3,4]

# %%
type(d)
# Out:
# list

# %%
s=['a','b','c','d']

# %%
type(s)
# Out:
# list

# %%
#you can add some values,remove values & make some modifications in the list

# %%
#Tuple
#if data is enclosed between open brackets it is tuple..

# %%
e=(1,2,3,4)

# %%
type(e)
# Out:
# tuple

# %%
# Note: The difference btw the tuple & list is,
#->YOU cannot make any changes to "Tuple"
#->You can make changes in "List"

# %%
#you can even convert list to array
p=np.array([1,2,3,4])

# %%
type(p)
# Out:
# numpy.ndarray

# %%
#Dictionary
#it will store ur data in key,value pair..ex: dic=(key:value)
#here key is 1 & excelr is value

# %%
f={1:'excelr',2:'solutions',3:'ltd'}

# %%
f
# Out:
# {1: 'excelr', 2: 'solutions', 3: 'ltd'}

# %%
type(f)
# Out:
# dict
